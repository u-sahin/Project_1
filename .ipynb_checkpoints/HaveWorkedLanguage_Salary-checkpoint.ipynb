# %%
# QUESTION:
# Is the salary dependent on the programming language learned?
# Which programming language is the most and least learned?

# %%
# import all necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as 

df = pd.read_csv('./data/survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
# only select columns needed
# also drop the NaN-values
clean_df = df[['HaveWorkedLanguage', 'Salary']].dropna()
clean_df
# Out:
#                                      HaveWorkedLanguage         Salary
# 2                                     Java; PHP; Python  113750.000000
# 14                                     Assembly; C; C++  100000.000000
# 17     C; Clojure; JavaScript; Matlab; Rust; SQL; Swift  130000.000000
# 22                                                 Java  100764.000000
# 25                                          Java; Scala  175000.000000
# ...                                                 ...            ...
# 51371                            Go; JavaScript; Python   74193.548387
# 51378            JavaScript; Objective-C; Python; Swift  107526.881720
# 51382                        C#; JavaScript; TypeScript   32258.064516
# 51387          C#; JavaScript; Python; SQL; VB.NET; VBA   58000.000000
# 51390                            JavaScript; PHP; Swift   40000.000000
#
# [12128 rows x 2 columns]

# %%
# split the HaveWorkedLanguage-column by ';' and stack its values

s = clean_df['HaveWorkedLanguage'].str.split('; ').apply(pd.Series, 1).stack()
s.index = s.index.droplevel(-1) # to line up with df's index
s.name = 'HaveWorkedLanguage' # needs a name to join
del clean_df['HaveWorkedLanguage']
clean_df = clean_df.join(s)

# %%
clean_df
# Out:
#          Salary HaveWorkedLanguage
# 2      113750.0               Java
# 2      113750.0                PHP
# 2      113750.0             Python
# 14     100000.0           Assembly
# 14     100000.0                  C
# ...         ...                ...
# 51387   58000.0             VB.NET
# 51387   58000.0                VBA
# 51390   40000.0         JavaScript
# 51390   40000.0                PHP
# 51390   40000.0              Swift
#
# [44718 rows x 2 columns]

# %%
# create a plot with a line-chart inside a bar-chart
ax= clean_df.groupby('HaveWorkedLanguage')['Salary'].count().plot(secondary_y=True, ylabel="Salary", rot=90, color="r", legend=True)
clean_df.groupby('HaveWorkedLanguage')['Salary'].mean().plot.bar(ylabel="Count of workers", color="b", ax=ax, legend=True)

plt.title('Salary per HaveWorkedLanguage')
plt.show()

# %%
# show the average salary in total
clean_df['Salary'].mean()
# Out:
# 57503.67149241554

# %%
# show all calculated average salaries and sort them in descending order
clean_df.groupby('HaveWorkedLanguage')['Salary'].mean().reset_index(name='mean').sort_values(['mean'], ascending=False)
# Out:
#    HaveWorkedLanguage          mean
# 4             Clojure  77494.043705
# 29          Smalltalk  76455.226730
# 26               Rust  73091.621163
# 11                 Go  71962.086934
# 13               Hack  71212.729056
# 22               Perl  70462.518553
# 10                 F#  69717.472684
# 28              Scala  68600.946263
# 9              Erlang  67908.272204
# 12             Groovy  65709.950021
# 25               Ruby  65581.261691
# 8              Elixir  65574.271317
# 24                  R  65080.869474
# 5        CoffeeScript  63474.436604
# 17              Julia  62989.142498
# 6         Common Lisp  62547.245503
# 20        Objective-C  61673.317588
# 23             Python  61641.073324
# 30              Swift  61267.300193
# 14            Haskell  61136.797795
# 18                Lua  61105.905579
# 31         TypeScript  59623.008951
# 3                 C++  58690.262754
# 2                  C#  58305.499895
# 1                   C  56663.800770
# ...

# %%
# count all calculated average salaries and sort them in descending order
clean_df.groupby('HaveWorkedLanguage')['Salary'].count().reset_index(name='count').sort_values(['count'], ascending=False)
# Out:
#    HaveWorkedLanguage  count
# 16         JavaScript   8132
# 27                SQL   6512
# 2                  C#   4597
# 15               Java   4572
# 23             Python   3442
# 21                PHP   3082
# 3                 C++   2166
# 1                   C   1684
# 31         TypeScript   1381
# 25               Ruby   1249
# 20        Objective-C    854
# 30              Swift    793
# 32             VB.NET    705
# 11                 Go    586
# 28              Scala    539
# 12             Groovy    500
# 22               Perl    444
# 5        CoffeeScript    432
# 0            Assembly    393
# 33                VBA    388
# 24                  R    386
# 19             Matlab    316
# 34     Visual Basic 6    272
# 18                Lua    248
# 10                 F#    169
# 14            Haskell    141
# 8              Elixir    140
# 4             Clojure    136
# 26               Rust    123
# 9              Erlang     87
# 29          Smalltalk     79
# ...

# %%
# Answer:
# The ones who have learned Clojure do have the highest average salary (at ~77,494.04), 
# while people who learned PHP do have the lowest salary (at ~ 44,780.66).
# Which means there is a gap of ~33,000.

# This means that the salary is acutally dependent from the learned programming language.
# As seen in the last list, the most learned language is Javascript, while the least learned is Julia.
# It is interresting to see that the average salary for these 
# two languages (Javascript: 56,396.92, Julia: ~62,989.14) does however look different.
# I assume this is because Julia is a language which is known by less people 
# and therefore the salary is above the total average of all languages (at ~57503.67).
