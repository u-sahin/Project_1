# %% [markdown]
# ## Business Understanding
#
# ### QUESTION
# Is the salary dependent on the programming language learned?
# Which programming language is the most and least learned?
#
# ### Reason
# Programming became more and more important over the past few years and will become even more important in the next few years.
# This is because there are now so many options what people can do by their own. To see which programming language does give the most and least salary, we will use this analysis as a basis.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functions import create_mean_and_count_plot

df = pd.read_csv('./data/survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %% [markdown]
# ## Data understanding
#
# **1.** Looking at the data

# %%
"The dataframe contains {} rows and {} columns.".format(df.shape[0], df.shape[1])
# Out:
# 'The dataframe contains 51392 rows and 154 columns.'

# %% [markdown]
# **2.**  Selected only necessary columns

# %%
language_df = df[['HaveWorkedLanguage', 'Salary']]
language_df
# Out:
#                                HaveWorkedLanguage    Salary
# 0                                           Swift       NaN
# 1                   JavaScript; Python; Ruby; SQL       NaN
# 2                               Java; PHP; Python  113750.0
# 3                          Matlab; Python; R; SQL       NaN
# 4                                             NaN       NaN
# ...                                           ...       ...
# 51387    C#; JavaScript; Python; SQL; VB.NET; VBA   58000.0
# 51388                                   Java; SQL       NaN
# 51389                                         NaN       NaN
# 51390                      JavaScript; PHP; Swift   40000.0
# 51391  Java; JavaScript; PHP; Python; Ruby; Swift       NaN
#
# [51392 rows x 2 columns]

# %% [markdown]
# **3.** Check how many NaN-values are avialable for HaveWorkedLanguage-column

# %%
nulls = language_df[language_df['HaveWorkedLanguage'].isnull()]
len(nulls)
# Out:
# 14767

# %% [markdown]
# ## Data Preperation
#
# **4.** Drop the NaN-values of all columns and reset the index

# %%
language_df = language_df.dropna().reset_index()

# %% [markdown]
# **5.** Split the HaveWorkedLanguage-column by ';' and stack its values

# %%
s = language_df['HaveWorkedLanguage'].str.split('; ').apply(pd.Series, 1).stack()
s.index = s.index.droplevel(-1) # to line up with df's index
s.name = 'HaveWorkedLanguage' # needs a name to join
del language_df['HaveWorkedLanguage']
merged_df = language_df.join(s)

# %% [markdown]
# **6.** Lets have a look at the new dataframe

# %%
merged_df
# Out:
#        index    Salary HaveWorkedLanguage
# 0          2  113750.0               Java
# 0          2  113750.0                PHP
# 0          2  113750.0             Python
# 1         14  100000.0           Assembly
# 1         14  100000.0                  C
# ...      ...       ...                ...
# 12126  51387   58000.0             VB.NET
# 12126  51387   58000.0                VBA
# 12127  51390   40000.0         JavaScript
# 12127  51390   40000.0                PHP
# 12127  51390   40000.0              Swift
#
# [44718 rows x 3 columns]

# %% [markdown]
# ## Data modeling
#
# **7.** The total average of all available salaries

# %%
merged_df['Salary'].mean()
# Out:
# 57503.67149241554

# %% [markdown]
# **8.** Show all calculated average salaries and sort them in descending order

# %%
merged_df.groupby('HaveWorkedLanguage')['Salary'].mean().reset_index(name='mean').sort_values(['mean'], ascending=False)
# Out:
#    HaveWorkedLanguage          mean
# 4             Clojure  77494.043705
# 29          Smalltalk  76455.226730
# 26               Rust  73091.621163
# 11                 Go  71962.086934
# 13               Hack  71212.729056
# 22               Perl  70462.518553
# 10                 F#  69717.472684
# 28              Scala  68600.946263
# 9              Erlang  67908.272204
# 12             Groovy  65709.950021
# 25               Ruby  65581.261691
# 8              Elixir  65574.271317
# 24                  R  65080.869474
# 5        CoffeeScript  63474.436604
# 17              Julia  62989.142498
# 6         Common Lisp  62547.245503
# 20        Objective-C  61673.317588
# 23             Python  61641.073324
# 30              Swift  61267.300193
# 14            Haskell  61136.797795
# 18                Lua  61105.905579
# 31         TypeScript  59623.008951
# 3                 C++  58690.262754
# 2                  C#  58305.499895
# 1                   C  56663.800770
# ...

# %% [markdown]
# **9.** Count all calculated average salaries and sort them in descending order

# %%
merged_df.groupby('HaveWorkedLanguage')['Salary'].count().reset_index(name='count').sort_values(['count'], ascending=False)
# Out:
#    HaveWorkedLanguage  count
# 16         JavaScript   8132
# 27                SQL   6512
# 2                  C#   4597
# 15               Java   4572
# 23             Python   3442
# 21                PHP   3082
# 3                 C++   2166
# 1                   C   1684
# 31         TypeScript   1381
# 25               Ruby   1249
# 20        Objective-C    854
# 30              Swift    793
# 32             VB.NET    705
# 11                 Go    586
# 28              Scala    539
# 12             Groovy    500
# 22               Perl    444
# 5        CoffeeScript    432
# 0            Assembly    393
# 33                VBA    388
# 24                  R    386
# 19             Matlab    316
# 34     Visual Basic 6    272
# 18                Lua    248
# 10                 F#    169
# 14            Haskell    141
# 8              Elixir    140
# 4             Clojure    136
# 26               Rust    123
# 9              Erlang     87
# 29          Smalltalk     79
# ...

# %% [markdown]
# ## Results evaluation
#
# **10.** Showing a chart with the salaries as primary-y-axis and the count of participants as secondary-y-axis. The x-axis is filled with the programming languages in alphabetical order.

# %%
plt = create_mean_and_count_plot(dataframe=merged_df, groupby=['HaveWorkedLanguage'], measure='Salary', \
                                 secondary_ylabel='Count of participants', title='Salary per HaveWorkedLanguage')
plt.show()

# %% [markdown]
# ### Answer
# The ones who have learned Clojure do have the highest average salary (at **~77,494.04**),
# while people who learned PHP do have the lowest salary (at **~44,780.66**).
# Which means there is a gap of **~33,000**.
#
# This means that the salary is acutally dependent from the learned programming language.
# As seen in the last list, the most learned language is Javascript, while the least learned is Julia.
# It is interesting to see that the average salary for these
# two languages (Javascript: **56,396.92**, Julia: **~62,989.14**) does however look different.
# I assume this is because Julia is a language which is known by less people
# and therefore the salary is above the total average of all languages (at **~57,503.67**).
